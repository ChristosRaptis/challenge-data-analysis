# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats

# %%
immo_dataset = pd.read_csv('fulldata.csv')

immo_dataset.head(15)
# Out:
#                 locality postal_code    region property_type subtype_property
# 0                 Deinze        9800  Flanders     APARTMENT        APARTMENT  \
# 1                  Halle        1500  Flanders         HOUSE            HOUSE
# 2                Antwerp        2060  Flanders     APARTMENT        APARTMENT
# 3                Antwerp        2018  Flanders     APARTMENT        APARTMENT
# 4                 Edegem        2650  Flanders     APARTMENT        APARTMENT
# 5                Tremelo        3128  Flanders         HOUSE            HOUSE
# 6            Tielt-Winge        3390  Flanders         HOUSE            HOUSE
# 7            Denderleeuw        9470  Flanders         HOUSE            HOUSE
# 8                 Knokke        8300  Flanders     APARTMENT        APARTMENT
# 9   Molenbeek-Saint-Jean        1080  Brussels     APARTMENT        APARTMENT
# 10              Machelen        1830  Flanders     APARTMENT        APARTMENT
# 11                  Pelt        3910  Flanders         HOUSE            HOUSE
# 12            Fauvillers        6637  Wallonie         HOUSE            HOUSE
# 13   Watermael-Boitsfort        1170  Brussels     APARTMENT        APARTMENT
# 14      Antwerpen Deurne        2100  Flanders         HOUSE            HOUSE
#
#        price  contruction_year      type_of_sale  number_of_rooms
# 0   395000.0            2023.0  residential_sale                2  \
# 1   385000.0               NaN  residential_sale                3
# 2   140000.0               NaN  residential_sale                1
# 3   215000.0               NaN  residential_sale                2
# 4   349900.0               NaN  residential_sale                2
# 5   380000.0            1993.0  residential_sale                4
# 6   510000.0            2024.0  residential_sale                5
# 7   339000.0               NaN  residential_sale                3
# 8   765000.0               NaN  residential_sale                2
# 9   339000.0               NaN  residential_sale                3
# 10  258000.0               NaN  residential_sale                2
# 11  349900.0               NaN  residential_sale                3
# 12  310000.0               NaN  residential_sale                3
# 13  285000.0               NaN  residential_sale                2
# 14  299000.0               NaN  residential_sale                5
#
#     living_area  ...  has_open_fire  has_terrace  terrace_area  has_garden
# 0          22.0  ...              0            1          12.0           1  \
# 1           NaN  ...              0            0           NaN           0
# 2           NaN  ...              0            1           8.0           0
# 3           NaN  ...              0            0           NaN           0
# 4           NaN  ...              0            1           NaN           0
# 5          40.0  ...              0            1           NaN           0
# 6          30.0  ...              0            1           NaN           0
# 7           NaN  ...              0            1           NaN           0
# 8           NaN  ...              0            1          10.0           0
# 9           NaN  ...              1            0           NaN           0
# 10          NaN  ...              0            0           NaN           0
# 11          NaN  ...              0            1           NaN           1
# 12          NaN  ...              0            1           NaN           1
# 13          NaN  ...              0            1           4.0           0
# 14         23.0  ...              0            0           NaN           0
#
#     garden_surface  habitable_surface  plot_land_surface  number_of_facades
# 0              NaN               99.0                NaN                4.0  \
# 1              NaN              158.0                NaN                NaN
# 2              NaN               44.0                NaN                NaN
# 3              NaN               75.0                NaN                NaN
# 4              NaN              103.0                NaN                NaN
# 5              NaN              220.0              863.0                4.0
# 6              NaN              224.0              693.0                3.0
# 7              NaN              165.0                NaN                NaN
# 8              NaN               96.0                NaN                NaN
# 9              NaN              140.0                NaN                NaN
# 10             NaN               77.0                NaN                NaN
# 11            45.0              180.0                NaN                NaN
# 12           255.0              175.0                NaN                NaN
# 13             NaN               68.0                NaN                NaN
# 14             NaN              250.0               64.0                2.0
#
#     has_swimming_pool  building_state
# 0                   0          AS_NEW
# 1                   0             NaN
# 2                   0             NaN
# 3                   0             NaN
# 4                   0             NaN
# 5                   0     TO_RENOVATE
# 6                   0          AS_NEW
# 7                   0             NaN
# 8                   0             NaN
# 9                   0             NaN
# 10                  0             NaN
# 11                  0             NaN
# 12                  0             NaN
# 13                  0             NaN
# 14                  0            GOOD
#
# [15 rows x 22 columns]

# %%
immo_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11243 entries, 0 to 11242
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   locality               11243 non-null  object
#  1   postal_code            11243 non-null  object
#  2   region                 11171 non-null  object
#  3   property_type          11243 non-null  object
#  4   subtype_property       11243 non-null  object
#  5   price                  11242 non-null  float64
#  6   contruction_year       2406 non-null   float64
#  7   type_of_sale           11243 non-null  object
#  8   number_of_rooms        11243 non-null  int64
#  9   living_area            3438 non-null   float64
#  10  kitchen_fully_equiped  3438 non-null   float64
#  11  is_furnished           11243 non-null  int64
#  12  has_open_fire          11243 non-null  int64
#  13  has_terrace            11243 non-null  int64
#  14  terrace_area           4678 non-null   float64
#  15  has_garden             11243 non-null  int64
#  16  garden_surface         2473 non-null   float64
#  17  habitable_surface      10636 non-null  float64
#  18  plot_land_surface      2735 non-null   float64
#  19  number_of_facades      2926 non-null   float64
#  20  has_swimming_pool      11243 non-null  int64
#  21  building_state         3030 non-null   object
# dtypes: float64(9), int64(6), object(7)
# memory usage: 1.9+ MB

# %% [markdown]
# Data Cleaning
#
# Fill empty values

# %%
missing_percentage = immo_dataset.isna().mean() * 100
print(missing_percentage)
# Out:
# locality                  0.000000
# postal_code               0.000000
# region                    0.640398
# property_type             0.000000
# subtype_property          0.000000
# price                     0.008894
# contruction_year         78.600018
# type_of_sale              0.000000
# number_of_rooms           0.000000
# living_area              69.420973
# kitchen_fully_equiped    69.420973
# is_furnished              0.000000
# has_open_fire             0.000000
# has_terrace               0.000000
# terrace_area             58.391888
# has_garden                0.000000
# garden_surface           78.004091
# habitable_surface         5.398915
# plot_land_surface        75.673753
# number_of_facades        73.974918
# has_swimming_pool         0.000000
# building_state           73.049898
# dtype: float64

# %% [markdown]
# Replace space in postal_code

# %%
immo_dataset['postal_code'] = immo_dataset['postal_code'].str.replace(' ', '')

# %% [markdown]
# Remove letters from postal codes.

# %%
immo_dataset['postal_code'] = immo_dataset['postal_code'].str.replace('MK', '')
immo_dataset['postal_code'] = immo_dataset['postal_code'].str.replace('AN', '')
immo_dataset['postal_code'] = immo_dataset['postal_code'].str.replace('KA', '')
immo_dataset['postal_code'] = immo_dataset['postal_code'].str.replace('AG', '')

# %% [markdown]
# Remove erronous Postal Codes (with more than 4 digits)

# %%
res = immo_dataset[immo_dataset['postal_code'].map(lambda x: len(x) >= 5)]
immo_dataset.drop(res.index, inplace=True)
print(immo_dataset['postal_code'].unique())
print(immo_dataset.shape)
# Out:
# ['9800' '1500' '2060' '2018' '2650' '3128' '3390' '9470' '8300' '1080'
#  '1830' '3910' '6637' '1170' '2100' '1370' '2940' '2610' '1050' '9050'
#  '8800' '9100' '9870' '1800' '2860' '2580' '9991' '9000' '8587' '8434'
#  '8810' '8770' '3630' '7900' '3221' '3730' '3800' '2280' '7912' '1020'
#  '2560' '2243' '9290' '1760' '2440' '8000' '4367' '9600' '4000' '4041'
#  '1440' '2830' '1200' '1030' '1070' '4100' '4690' '4020' '8370' '3680'
#  '9070' '3070' '8860' '2450' '8301' '2660' '3830' '3500' '3840' '3720'
#  '4820' '6940' '1653' '4430' '2620' '4500' '9770' '4102' '6792' '9750'
#  '1040' '1410' '1820' '9120' '8630' '9472' '3000' '9820' '3010' '1180'
#  '1000' '2170' '2850' '2340' '1790' '8740' '7190' '8500' '1495' '6030'
#  '3990' '3150' '9968' '1300' '1140' '5100' '2970' '7620' '9160' '9032'
#  '9900' '9300' '9660' '1210' '1060' '8690' '1755' '8647' '3020' '1700'
#  '4340' '1090' '1480' '8930' '6042' '9260' '7940' '8660' '1420' '1740'
#  '2000' '1780' '4040' '1083' '2570' '2380' '4680' '1160' '5030' '6750'
#  '1150' '2270' '7500' '2020' '3980' '2430' '2400' '2050' '7333' '8670'
#  '9890' '1330' '2600' '9520' '9340' '7712' '9200' '6181' '6060' '1301'
#  '4450' '2920' '2040' '6040' '7134' '7020' '2950' '3012' '3300' '6840'
#  '3970' '1930' '4101' '1400' '2870' '8792' '1910' '2900' '1970' '9040'
#  '1348' '6230' '4602' '9473' '2500' '9280' '2845' '4420' '1600' '7390'
#  '3270' '6890' '9506' '9500' '3272' '2222' '3120' '2230' '9090' '2800'
#  '3140' '7700' '1831' '2110' '2360' '3001' '4802' '6140' '6900' '2300'
#  '9230' '1120' '2140' '9140' '4357' '4360' '8790' '9400' '6870' '1190'
#  '9042' '1570' '4257' '1651' '2812' '9170' '1730' '6031' '6180' '3600'
#  '2221' '2930' '7033' '1650' '4400' '5590' '3080' '3581' '1950' '3090'
#  '1380' '5377' '1501' '1082' '3920' '2590' '5002' '9690' '5575' '3540'
#  '4470' '4550' '8200' '9270' '5300' '9850' '1702' '1310' '1785' '3320'
#  '8600' '3440' '8480' '8560' '4460' '8890' '4845' '1340' '6810' '1770'
#  '4280' '1502' '2235' '9990' '2350' '2250' '2460' '2880' '9255' '5081'
#  '1853' '9570' '1850' '4480' '9620' '4121' '8310' '9700' '3130' '7170'
#  '9790' '3370' '1932' '1470' '4841' '9860' '8610' '3650' '3620' '8850'
#  '7850' '9112' '4920' '4651' '5004' '1390' '3460' '9950' '4051' '4130'
#  '6700' '3580' '7370' '7080' '3380' '4350' '4910' '4980' '9961' '7522'
#  '6590' '4800' '6001' '1457' '4560' '5370' '2390' '1620' '2480' '7140'
#  '4160' '8430' '7711' '8420' '8870' '8530' '3971' '8501' '6200' '8972'
#  '9220' '6790' '1840' '8900' '8880' '1731' '9402' '9420' '1450' '4520'
#  '8380' '6830' '5334' '2520' '7812' '1325' '8540' '8580' '8520' '9060'
#  '6000' '8400' '9041' '8450' '1320' '9910' '3290' '9180' '3450' '8377'
#  '7972' '9190' '9130' '3890' '9150' '8840' '2310' '1703' '6980' '5620'
#  '9080' '9940' '2640' '1435' '6880' '4890' '4683' '4031' '6791' '6960'
#  '8552' '2840' '8680' '8750' '7110' '8550' '9310' '9052' '9051' '8730'
#  '1750' '9111' '9240' '8620' '4684' '7130' '8570' '2220' '2200' '4610'
#  '2470' '2980' '6690' '6043' '1630' '1880' '8650' '8760' '8700' '6640'
#  '5530' '8780' '6600' '3400' '4032' '5580' '6032' '4140' '7502' '8340'
#  '2180' '7531' '3583' '9667' '7890' '3520' '2890' '1654' '9030' '2530'
#  '5020' '9810' '5000' '7350' '5573' '7866' '5600' '3900' '3560' '4530'
#  '9031' '3454' '2550' '7904' '6800' '4600' '4540' '3053' '6760' '4682'
#  '8830' '9250' '4624' '9630' '4217' '5520' '1640' '3211' '7000' '3110'
#  '7340' '6150' '3200' '1861' '5101' '1460' '5032' '7090' '3870' '1601'
#  '6831' '8460' '9960' '2150' '8710' '7034' '7804' '7870' '4053' '1980'
#  '7911' '5060' '3740' '8510' '1490' '1860' '6941' '2240' '3891' '3850'
#  '9971' '2260' '7536' '4120' '4537' '6724' '3510' '7160' '6740' '5650'
#  '9450' '1933' '1130' '4451' '6142' '1547' '1745' '1701' '7301' '1742'
#  '1741' '4170' '5660' '5630' '5651' '1341' '4260' '4317' '7971' '1081'
#  '7050' '2160' '4030' '7100' '2491' '6630' '4342' '3590' '2070' '1421'
#  '9830' '7740' '3530' '8791' '6464' '4870' '4050' '7180' '9880' '1652'
#  '6534' '4190' '3210' '7060' '1540' '5340' '6860' '2275' '9550' '4877'
#  '4141' '1350' '4860' '4750' '8210' '9404' '4300' '6224' '2820' '6238'
#  '7300' '6530' '2811' '6500' '1342' '6280' '6717' '5680' '3945' '9840'
#  '1430' '7387' '2490' '1428' '7320' '9572' '3271' '5670' '2540' '3111'
#  '9320' '7021' '3052' '7063' '8820' '5024' '6990' '4576' '4653' '4551'
#  '5350' '2431' '3470' '3570' '5330' '5500' '4970' '3550' '6851' '7822'
#  '5540' '2960' '7750' '4171' '4681' '3700' '5640' '5190' '3582' '6120'
#  '3051' '6824' '3040' '3078' '3071' '8940' '4710' '8020' '5570' '6240'
#  '2910' '7760' '2382' '2370' '6850' '7181' '1331' '4122' '2627' '6061'
#  '9831' '3545' '6041' '7332' '1332' '6921' '7141' '4672' '6929' '9688'
#  '2630' '6720' '6210' '4900' '4577' '6741' '4621' '4840' '7330' '5310'
#  '7830' '7880' '8470' '6820' '6044' '4700' '4180' '9451' '4570' '7022'
#  '3770' '3201' '7061' '2330' '3118' '7600' '7608' '9980' '6183' '6220'
#  '7331' '8755' '9881' '3806' '6250' '8980' '4524' '4801' '5070' '6567'
#  '7040' '3670' '9920' '6010' '8920' '7860' '6660' '7910' '9988' '9185'
#  '3960' '3690' '7730' '8531' '4720' '8211' '9930' '4432' '7382' '4620'
#  '5170' '5360' '7120' '3191' '2861' '5537' '4052' '4287' '6780' '4987'
#  '7943' '3060' '4590' '8970' '4770' '6680' '4607' '8691' '7542' '1670'
#  '6997' '3050' '5555' '8490' '4218' '1761' '6440' '3660' '2030' '5550'
#  '1367' '2990' '6838' '6987' '3190' '7801' '7621' '6670' '8432' '9552'
#  '3018' '4508' '1982' '6470' '3401' '6663' '6953' '7032' '9308' '3202'
#  '8793' '5572' '4557' '3511' '7783' '4960' '6782' '7642' '8904' '6666'
#  '6833' '7380' '4771' '3621' '4821' '8551' '5621' '7604' '7543' '6593'
#  '1981' '6560' '6730' '5560' '3360' '3391' '3790' '4210' '7012' '6687'
#  '7131' '8573' '8511' '5380' '6672' '8950' '8720' '1560' '8581' '3665'
#  '2223' '9401' '4608' '7504' '2547' '4650' '6971' '4601' '6221' '3950'
#  '3189' '7864' '4161' '6141' '5150' '6823' '6182' '5543' '4623' '4347'
#  '8953' '8640' '7322' '5140' '5001' '8902' '5503' '7970' '3640' '6662'
#  '7802' '7640' '1315' '6460' '3220' '4830' '2242' '7070' '8553' '4721'
#  '7334' '6769' '5022' '6661' '6927' '5031' '7030' '4042' '6223' '6836'
#  '6767' '3930' '3193' '7534' '5646' '4990' '2381' '3940' '5376' '7950'
#  '9931' '7863' '5542' '7540' '7742' '3384' '5544' '3473' '4837' '8978'
#  '1602' '2290' '4950' '4219' '6762' '4525' '8908' '3350' '7810' '6970'
#  '3321' '7973' '6671' '7901' '4670' '6781' '7641' '4250' '2801' '6692'
#  '4671' '1357' '8954' '7800' '8554' '9521' '7321' '6834' '6747' '3061'
#  '8582' '6920' '4633' '7603' '7780' '1360' '9680' '1851' '4630' '5541']
# (11190, 22)

# %% [markdown]
# We dropped columns from main data because it had hight % of missing values.

# %%
drop_columns = ['locality', 'contruction_year', 'subtype_property', 'living_area', 'kitchen_fully_equiped', 'terrace_area', 'garden_surface', 'plot_land_surface', 'number_of_facades', 'building_state']
immo_dataset.drop(drop_columns , axis=1, inplace=True)
immo_dataset.head(10)
# Out:
#   postal_code    region property_type     price      type_of_sale
# 0        9800  Flanders     APARTMENT  395000.0  residential_sale  \
# 1        1500  Flanders         HOUSE  385000.0  residential_sale
# 2        2060  Flanders     APARTMENT  140000.0  residential_sale
# 3        2018  Flanders     APARTMENT  215000.0  residential_sale
# 4        2650  Flanders     APARTMENT  349900.0  residential_sale
# 5        3128  Flanders         HOUSE  380000.0  residential_sale
# 6        3390  Flanders         HOUSE  510000.0  residential_sale
# 7        9470  Flanders         HOUSE  339000.0  residential_sale
# 8        8300  Flanders     APARTMENT  765000.0  residential_sale
# 9        1080  Brussels     APARTMENT  339000.0  residential_sale
#
#    number_of_rooms  is_furnished  has_open_fire  has_terrace  has_garden
# 0                2             0              0            1           1  \
# 1                3             0              0            0           0
# 2                1             0              0            1           0
# 3                2             0              0            0           0
# 4                2             0              0            1           0
# 5                4             0              0            1           0
# 6                5             0              0            1           0
# 7                3             0              0            1           0
# 8                2             1              0            1           0
# 9                3             0              1            0           0
#
#    habitable_surface  has_swimming_pool
# 0               99.0                  0
# 1              158.0                  0
# 2               44.0                  0
# 3               75.0                  0
# 4              103.0                  0
# 5              220.0                  0
# 6              224.0                  0
# 7              165.0                  0
# 8               96.0                  0
# 9              140.0                  0

# %% [markdown]
# Define duplicates.

# %%
duplicate_rows = immo_dataset.duplicated()
duplicate_data = immo_dataset[duplicate_rows]

print(duplicate_data)
# Out:
#       postal_code    region property_type      price      type_of_sale
# 191          2830  Flanders     APARTMENT   225000.0  residential_sale  \
# 218          4820  Wallonie     APARTMENT    99000.0  residential_sale
# 255          1300  Wallonie     APARTMENT   299000.0  residential_sale
# 315          4101  Wallonie         HOUSE   239500.0  residential_sale
# 479          1180  Brussels     APARTMENT   245000.0  residential_sale
# ...           ...       ...           ...        ...               ...
# 11125        6120  Wallonie         HOUSE   374000.0  residential_sale
# 11133        9060  Flanders     APARTMENT   149000.0  residential_sale
# 11172        9500  Flanders         HOUSE   125000.0  residential_sale
# 11194        1180  Brussels         HOUSE  1450000.0  residential_sale
# 11212        1070  Brussels         HOUSE   749000.0  residential_sale
#
#        number_of_rooms  is_furnished  has_open_fire  has_terrace  has_garden
# 191                  3             0              1            1           0  \
# 218                  2             0              0            1           0
# 255                  1             0              0            1           0
# 315                  3             0              1            0           1
# 479                  1             0              0            1           0
# ...                ...           ...            ...          ...         ...
# 11125                3             0              0            1           1
# 11133                2             0              0            1           0
# 11172                2             0              0            0           0
# 11194                4             0              0            1           1
# 11212                4             0              0            1           1
#
#        habitable_surface  has_swimming_pool
# 191                105.0                  0
# 218                 94.0                  0
# 255                 82.0                  0
# 315                143.0                  0
# 479                 80.0                  0
# ...                  ...                ...
# 11125              165.0                  0
# 11133               75.0                  0
# 11172               85.0                  0
# 11194              338.0                  0
# 11212              320.0                  1
#
# [298 rows x 12 columns]

# %%
immo_dataset = immo_dataset.reset_index(drop=True)

# %% [markdown]
# Remove duplicates.

# %%
immo_dataset.drop_duplicates(inplace=True)
immo_dataset.to_csv('immo_clean1.csv')

# %%
immo_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10892 entries, 0 to 11189
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postal_code        10892 non-null  object
#  1   region             10873 non-null  object
#  2   property_type      10892 non-null  object
#  3   price              10891 non-null  float64
#  4   type_of_sale       10892 non-null  object
#  5   number_of_rooms    10892 non-null  int64
#  6   is_furnished       10892 non-null  int64
#  7   has_open_fire      10892 non-null  int64
#  8   has_terrace        10892 non-null  int64
#  9   has_garden         10892 non-null  int64
#  10  habitable_surface  10299 non-null  float64
#  11  has_swimming_pool  10892 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# Remove spaces from columns with objects.

# %%
#remove space from all columns
immo_dataset_space_removed = immo_dataset.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
print(immo_dataset_space_removed)
# Out:
#       postal_code    region property_type     price      type_of_sale
# 0            9800  Flanders     APARTMENT  395000.0  residential_sale  \
# 1            1500  Flanders         HOUSE  385000.0  residential_sale
# 2            2060  Flanders     APARTMENT  140000.0  residential_sale
# 3            2018  Flanders     APARTMENT  215000.0  residential_sale
# 4            2650  Flanders     APARTMENT  349900.0  residential_sale
# ...           ...       ...           ...       ...               ...
# 11185        2830  Flanders     APARTMENT  289000.0  residential_sale
# 11186        2830  Flanders     APARTMENT  291000.0  residential_sale
# 11187        2830  Flanders     APARTMENT  281000.0  residential_sale
# 11188        2990  Flanders         HOUSE  225000.0  residential_sale
# 11189        2830  Flanders     APARTMENT  309000.0  residential_sale
#
#        number_of_rooms  is_furnished  has_open_fire  has_terrace  has_garden
# 0                    2             0              0            1           1  \
# 1                    3             0              0            0           0
# 2                    1             0              0            1           0
# 3                    2             0              0            0           0
# 4                    2             0              0            1           0
# ...                ...           ...            ...          ...         ...
# 11185                2             0              0            1           1
# 11186                2             0              0            1           1
# 11187                2             0              0            1           1
# 11188                2             0              0            0           1
# 11189                2             0              0            1           1
#
#        habitable_surface  has_swimming_pool
# 0                   99.0                  0
# 1                  158.0                  0
# 2                   44.0                  0
# 3                   75.0                  0
# 4                  103.0                  0
# ...                  ...                ...
# 11185              102.0                  0
# 11186               98.0                  0
# 11187               93.0                  0
# 11188               65.0                  0
# 11189              103.0                  0
#
# [10892 rows x 12 columns]

# %% [markdown]
# Count empty values.

# %%
#Find empty values
empty_values = immo_dataset.isna()

#Count the number of empty values in each column
empty_count = empty_values.sum()

#Display the columns with empty values
print("Columns with empty values:")
print(empty_count[empty_count > 0])
# Out:
# Columns with empty values:
# region                19
# price                  1
# habitable_surface    593
# dtype: int64

# %% [markdown]
# Data Analysis

# %%
immo_dataset.shape
# Out:
# (10892, 12)

# %%
immo_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10892 entries, 0 to 11189
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postal_code        10892 non-null  object
#  1   region             10873 non-null  object
#  2   property_type      10892 non-null  object
#  3   price              10891 non-null  float64
#  4   type_of_sale       10892 non-null  object
#  5   number_of_rooms    10892 non-null  int64
#  6   is_furnished       10892 non-null  int64
#  7   has_open_fire      10892 non-null  int64
#  8   has_terrace        10892 non-null  int64
#  9   has_garden         10892 non-null  int64
#  10  habitable_surface  10299 non-null  float64
#  11  has_swimming_pool  10892 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# Percentage of empty values.

# %%
missing_percentage = immo_dataset.isna().mean() * 100
print(missing_percentage)
# Out:
# postal_code          0.000000
# region               0.174440
# property_type        0.000000
# price                0.009181
# type_of_sale         0.000000
# number_of_rooms      0.000000
# is_furnished         0.000000
# has_open_fire        0.000000
# has_terrace          0.000000
# has_garden           0.000000
# habitable_surface    5.444363
# has_swimming_pool    0.000000
# dtype: float64

# %% [markdown]
# Find correlation between price and other variables

# %%
categorical_columns = ['region', 'property_type', 'type_of_sale']
# Convert the categorical 'locality' column to numerical using one-hot encoding
encoded_data = pd.get_dummies(immo_dataset, columns=categorical_columns)

correlation_coefficient = encoded_data.corr()[['price']]

# Print the correlation coefficients

print(correlation_coefficient.sort_values(by=['price'], ascending=False))
# Out:
#                                                   price
# price                                          1.000000
# habitable_surface                              0.551158
# number_of_rooms                                0.365303
# has_swimming_pool                              0.212725
# region_Brussels                                0.185675
# has_terrace                                    0.109865
# has_garden                                     0.067707
# property_type_HOUSE                            0.048558
# type_of_sale_residential_sale                  0.043214
# region_Flanders                                0.037156
# is_furnished                                   0.010790
# type_of_sale_annuity_lump_sum                 -0.007899
# type_of_sale_first_session_with_reserve_price -0.010222
# has_open_fire                                 -0.035966
# type_of_sale_annuity_monthly_amount           -0.041882
# property_type_APARTMENT                       -0.048558
# postal_code                                   -0.109748
# region_Wallonie                               -0.193304

# %% [markdown]
# Remove 'type_of_sale' column.

# %%
drop_columns_type = ['type_of_sale']
immo_dataset = immo_dataset.drop(drop_columns_type, axis=1)
immo_dataset.head(10)
# Out:
#    postal_code    region property_type     price  number_of_rooms
# 0         9800  Flanders     APARTMENT  395000.0                2  \
# 1         1500  Flanders         HOUSE  385000.0                3
# 2         2060  Flanders     APARTMENT  140000.0                1
# 3         2018  Flanders     APARTMENT  215000.0                2
# 4         2650  Flanders     APARTMENT  349900.0                2
# 6         3390  Flanders         HOUSE  510000.0                5
# 7         9470  Flanders         HOUSE  339000.0                3
# 8         8300  Flanders     APARTMENT  765000.0                2
# 9         1080  Brussels     APARTMENT  339000.0                3
# 13        1170  Brussels     APARTMENT  285000.0                2
#
#     is_furnished  has_open_fire  has_terrace  has_garden  habitable_surface
# 0              0              0            1           1               99.0  \
# 1              0              0            0           0              158.0
# 2              0              0            1           0               44.0
# 3              0              0            0           0               75.0
# 4              0              0            1           0              103.0
# 6              0              0            1           0              224.0
# 7              0              0            1           0              165.0
# 8              1              0            1           0               96.0
# 9              0              1            0           0              140.0
# 13             0              0            1           0               68.0
#
#     has_swimming_pool  price_per_sqm
# 0                   0    3989.898990
# 1                   0    2436.708861
# 2                   0    3181.818182
# 3                   0    2866.666667
# 4                   0    3397.087379
# 6                   0    2276.785714
# 7                   0    2054.545455
# 8                   0    7968.750000
# 9                   0    2421.428571
# 13                  0    4191.176471

# %% [markdown]
# Plot correlation between price and other variables.

# %%
# Define categorical columns.
categorical_columns = ['region', 'property_type']

# Convert the categorical 'locality' column to numerical using one-hot encoding
encoded_data = pd.get_dummies(immo_dataset, columns=categorical_columns)

# Calculate the correlation using Pearson method
pearson_corr = encoded_data.corr(method='pearson')

# Sort the correlation values in descending order
sorted_correlation = pearson_corr.sort_values(by='price',ascending=False)

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.bar(sorted_correlation.index, sorted_correlation['price'])
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient (no units)')
plt.title('Correlation between Price and Other Variables')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# Plot Correlation Heatmap.

# %%
# Define categorical columns.
categorical_columns = ['region', 'property_type']

# Convert the categorical 'locality' column to numerical using one-hot encoding
encoded_data = pd.get_dummies(immo_dataset, columns=categorical_columns)

# Calculate the correlation using Pearson method
pearson_corr = encoded_data.corr(method='pearson')
# pearson_corr_filtered = pearson_corr[pearson_corr >= 0.5].sort_values(by= 'price', ascending=False)

# Plotting the correlation heatmap
plt.figure(figsize=(16, 16))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm')
plt.title('Pearson Correlation Heatmap')
plt.show()

# %% [markdown]
# How are variables correlated to each other?

# %% [markdown]
# There is a positive correlation between number of rooms and habitable surface.
# Also positive correlation between number of rooms and type of property:house.
# Positive correaltion between price and habitable surface.

# %% [markdown]
# Calculate correlation of all variables between them.

# %%
# Define categorical columns.
categorical_columns = ['region', 'property_type']
# Convert the categorical 'locality' column to numerical using one-hot encoding
encoded_data = pd.get_dummies(immo_dataset, columns=categorical_columns)

# Calculate correlation coefficient.
correlation_coefficient = encoded_data.corr()

# Print the correlation coefficients
print(correlation_coefficient)
# Out:
#                          postal_code     price  number_of_rooms  is_furnished
# postal_code                 1.000000 -0.103789        -0.003994      0.078013  \
# price                      -0.103789  1.000000         0.372627      0.009823
# number_of_rooms            -0.003994  0.372627         1.000000     -0.100210
# is_furnished                0.078013  0.009823        -0.100210      1.000000
# has_open_fire              -0.106278 -0.041333         0.029849     -0.018724
# has_terrace                -0.132090  0.116296         0.001980     -0.000763
# has_garden                  0.027906  0.077716         0.295925     -0.073244
# habitable_surface          -0.030829  0.585582         0.724331     -0.108865
# has_swimming_pool          -0.023769  0.227258         0.107024      0.013930
# price_per_sqm              -0.000238  0.255436        -0.056881      0.076754
# region_Brussels            -0.560411  0.181634        -0.061893      0.010549
# region_Flanders             0.480634  0.005084         0.000295      0.038082
# region_Wallonie            -0.029845 -0.177421         0.059476     -0.053908
# property_type_APARTMENT    -0.146925 -0.062181        -0.537272      0.121936
# property_type_HOUSE         0.146925  0.062181         0.537272     -0.121936
#
#                          has_open_fire  has_terrace  has_garden
# postal_code                  -0.106278    -0.132090    0.027906  \
# price                        -0.041333     0.116296    0.077716
# number_of_rooms               0.029849     0.001980    0.295925
# is_furnished                 -0.018724    -0.000763   -0.073244
# has_open_fire                 1.000000    -0.036378    0.062562
# has_terrace                  -0.036378     1.000000    0.053401
# has_garden                    0.062562     0.053401    1.000000
# habitable_surface             0.047578     0.006308    0.267788
# has_swimming_pool            -0.022189     0.050302    0.058744
# price_per_sqm                -0.054438     0.035205   -0.069992
# region_Brussels              -0.119247     0.093375   -0.149253
# region_Flanders              -0.008910    -0.083664    0.040965
# region_Wallonie               0.122407     0.009243    0.094521
# property_type_APARTMENT      -0.020752     0.136663   -0.444770
# property_type_HOUSE           0.020752    -0.136663    0.444770
#
#                          habitable_surface  has_swimming_pool  price_per_sqm
# postal_code                      -0.030829          -0.023769      -0.000238  \
# price                             0.585582           0.227258       0.255436
# number_of_rooms                   0.724331           0.107024      -0.056881
# is_furnished                     -0.108865           0.013930       0.076754
# has_open_fire                     0.047578          -0.022189      -0.054438
# has_terrace                       0.006308           0.050302       0.035205
# has_garden                        0.267788           0.058744      -0.069992
# habitable_surface                 1.000000           0.203269      -0.078792
# has_swimming_pool                 0.203269           1.000000       0.101450
# price_per_sqm                    -0.078792           0.101450       1.000000
# region_Brussels                  -0.013505          -0.013601       0.074357
# region_Flanders                   0.024002          -0.020780       0.031724
# region_Wallonie                  -0.013759           0.022235      -0.108301
# property_type_APARTMENT          -0.490164          -0.062458       0.144745
# property_type_HOUSE               0.490164           0.062458      -0.144745
#
#                          region_Brussels  region_Flanders  region_Wallonie
# postal_code                    -0.560411         0.480634        -0.029845  \
# price                           0.181634         0.005084        -0.177421
# number_of_rooms                -0.061893         0.000295         0.059476
# is_furnished                    0.010549         0.038082        -0.053908
# has_open_fire                  -0.119247        -0.008910         0.122407
# has_terrace                     0.093375        -0.083664         0.009243
# has_garden                     -0.149253         0.040965         0.094521
# habitable_surface              -0.013505         0.024002        -0.013759
# has_swimming_pool              -0.013601        -0.020780         0.022235
# price_per_sqm                   0.074357         0.031724        -0.108301
# region_Brussels                 1.000000        -0.566655        -0.283536
# region_Flanders                -0.566655         1.000000        -0.627043
# region_Wallonie                -0.283536        -0.627043         1.000000
# property_type_APARTMENT         0.295874        -0.114568        -0.148172
# property_type_HOUSE            -0.295874         0.114568         0.148172
#
#                          property_type_APARTMENT  property_type_HOUSE
# postal_code                            -0.146925             0.146925
# price                                  -0.062181             0.062181
# number_of_rooms                        -0.537272             0.537272
# is_furnished                            0.121936            -0.121936
# has_open_fire                          -0.020752             0.020752
# has_terrace                             0.136663            -0.136663
# has_garden                             -0.444770             0.444770
# habitable_surface                      -0.490164             0.490164
# has_swimming_pool                      -0.062458             0.062458
# price_per_sqm                           0.144745            -0.144745
# region_Brussels                         0.295874            -0.295874
# region_Flanders                        -0.114568             0.114568
# region_Wallonie                        -0.148172             0.148172
# property_type_APARTMENT                 1.000000            -1.000000
# property_type_HOUSE                    -1.000000             1.000000

# %% [markdown]
# Which variables have the greatest influence on the price?

# %% [markdown]
# The variables with the most influence on property price are:
#
# Habitable surface
#
# Number of rooms
#
# Presence of swimming pool
#
# Region: Brussels
#
# Presence of terrace.

# %% [markdown]
# Which variables have the least influence on the price?

# %% [markdown]
# The variables with the least influence on price are:
#
# Region:Flanders
#
# If it is furnished
#
# If it has open fire

# %% [markdown]
# How many qualitative and quantitative variables are there? How would you transform these values into numerical values?

# %% [markdown]
# We have three quantitative and eight qualitative variables.

# %%
immo_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8722 entries, 0 to 11189
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   postal_code        8722 non-null   object
#  1   region             8713 non-null   object
#  2   property_type      8722 non-null   object
#  3   price              8721 non-null   float64
#  4   number_of_rooms    8722 non-null   int64
#  5   is_furnished       8722 non-null   int64
#  6   has_open_fire      8722 non-null   int64
#  7   has_terrace        8722 non-null   int64
#  8   has_garden         8722 non-null   int64
#  9   habitable_surface  8273 non-null   float64
#  10  has_swimming_pool  8722 non-null   int64
#  11  price_per_sqm      8272 non-null   float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 885.8+ KB

# %% [markdown]
# Percentage of missing values per column?

# %%
missing_percentage = immo_dataset.isna().mean() * 100
print(missing_percentage)
# Out:
# postal_code          0.000000
# region               0.103187
# property_type        0.000000
# price                0.011465
# number_of_rooms      0.000000
# is_furnished         0.000000
# has_open_fire        0.000000
# has_terrace          0.000000
# has_garden           0.000000
# habitable_surface    5.147902
# has_swimming_pool    0.000000
# price_per_sqm        5.159367
# dtype: float64

# %% [markdown]
# Step 3 : Data Interpretation

# %% [markdown]
# Plot the outliers.

# %%
#Convert 'price' column to Pandas Series
price_series = pd.Series(immo_dataset['price'])

#Create the scatter plot
plt.scatter(range(len(price_series)), price_series)

#Set plot title and labels
plt.title('Scatter plot for Price Variation')
plt.xlabel('Number of properties')
plt.ylabel('Price: 100.000 euros')
plt.savefig("outliers_plot.jpg")

#Display the scatter plot
plt.show()

# %%
immo_dataset.drop(immo_dataset[(immo_dataset['price'] >= 2000000) & (immo_dataset['postal_code'] == '9400')].index, inplace=True)
property_counts = immo_dataset['postal_code'].value_counts()
immo_dataset = immo_dataset[immo_dataset['postal_code'].isin(property_counts[property_counts >= 10].index)]
immo_dataset.drop(immo_dataset[(immo_dataset['habitable_surface'] <=20)].index, inplace=True)
immo_dataset.to_csv("outliersremoved.csv")

# %% [markdown]
# Which variables would you delete and why ?

# %% [markdown]
#  'contruction_year',  'living_area', 'kitchen_fully_equiped', 'terrace_area', 'garden_surface', 'plot_land_surface', 'number_of_facades', 'building_state'
#
# We deleted the above variables beacause they had a significant percentage of missing values.
#
# 'subtype_property',type_of_sale.
#
# We deleted the above variables beacause they had no significant influence on the price of properties.
#
# 'locality',
#
# we deleted this variable because it wasn't useful to our analysis, we used postal code instead.

# %% [markdown]
# Represent the number of properties according to their surface using a histogram.

# %%
# Extract the 'habitable_surface' data
surface = immo_dataset['habitable_surface']

# Create the histogram
plt.hist(surface, bins=50, edgecolor='black')

# Label the axes and add a title
plt.xlabel('Surface (sq. meters)',fontsize=12)
plt.ylabel('Number of Properties',fontsize=12)
plt.title('Number of properties according to their surface')
plt.savefig("histogram_properties.jpg")

# Display the histogram
plt.show()

# %% [markdown]
# In your opinion, which 5 variables are the most important and why?

# %% [markdown]
# The variables with the most influence on property price are:
#
# Habitable surface: the biggest the surface the biggest the price.
#
# Number of rooms : construction cost increases as the number of room increases.
#
# Presence of swimming pool: it is a luxury.
#
# Region: Brussels : great population density -> higher demand over supply
#
# Presence of terrace: convenience, being able to sit and drink your coffee.

# %% [markdown]
# What are the most expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %%
# Calculate price per square meter
immo_dataset['price_per_sqm'] = immo_dataset['price'] / immo_dataset['habitable_surface']

# Group by region and calculate the average price, median price, and price per square meter
region_stats = immo_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median')    
)

# Sort the regions based on the index (region names) in ascending order
sorted_regions = region_stats.sort_index()

# Sort the regions based on the average price in descending order
most_expensive_regions = region_stats.sort_values(by='average_price', ascending=False).head(5)

# Print the most expensive regions and their corresponding statistics
print("Most Expensive Regions in Belgium:")
print(most_expensive_regions)
# Out:
# Most Expensive Regions in Belgium:
#              average_price  median_price
# postal_code
# 8300          1.345862e+06      942500.0
# 1640          1.235385e+06      995000.0
# 1050          1.014677e+06      699000.0
# 1380          9.031683e+05      597000.0
# 1950          8.244333e+05      657500.0

# %%
# Calculate price per square meter
immo_dataset['price_per_sqm'] = immo_dataset['price'] / immo_dataset['habitable_surface']

# Group by postal code and calculate the average price and median price
postal_code_stats = immo_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)

# Sort the postal codes based on the average price in ascending order
most_expensive_postal_codes_average = postal_code_stats.nlargest(10, 'average_price')
most_expensive_postal_codes_median = postal_code_stats.nlargest(10, 'median_price')

labels = most_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()
width = 0.35
ax.bar(x - width/2, most_expensive_postal_codes_average['average_price'], width, label='Average')
ax.bar(x + width/2, most_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')
ax.set_xlabel('Municipalities', fontsize=12,)
ax.set_ylabel('Price', fontsize=12, )
ax.set_title('Average and Median for Most Expensive Municipalities in Belgium')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("belgium_expensive_MM.jpg")

plt.show()

# %%
# Group by postal code and calculate the price per square meter
postal_code_stats = immo_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)
# Get the most expensive postal codes
most_expensive_postal_codes = postal_code_stats.nlargest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = most_expensive_postal_codes['price_per_sqm']
labels = most_expensive_postal_codes.index

fig, ax = plt.subplots()
width = 0.35
ax.barh(labels, price_per_square_meter_values)
ax.set_xlabel('Price per Square Meter')
ax.set_ylabel('Municipalities')
ax.set_title('Most Expensive Municipalities in Belgium')
ax.tick_params(axis='x', rotation=45)
for index, value in enumerate(price_per_square_meter_values):
    label = format(int(value), ',')
    plt.annotate(label, xy=(value-1500, index-0.1), color='white')
plt.tight_layout()
plt.savefig("belgium_expensive_PSQM.jpg")

plt.show()

# %% [markdown]
# What are the most expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %%
# Filter the dataset for Wallonia
wallonia_dataset = immo_dataset[immo_dataset['region'] == 'Wallonie']

# Group by postal code and calculate the average price andmedian price
postal_code_stats = wallonia_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)

# Sort the postal codes based on the average price in ascending order
most_expensive_postal_codes_average = postal_code_stats.nlargest(10, 'average_price')
most_expensive_postal_codes_median = postal_code_stats.nlargest(10, 'median_price')

labels = most_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()

width = 0.35

ax.bar(x - width/2, most_expensive_postal_codes_average['average_price'], width, label='Mean')
ax.bar(x + width/2, most_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')

ax.set_xlabel('Municipalities')
ax.set_ylabel('Price in euros')
ax.set_title('Mean and Median Comparison - Most Expensive Municipalities in Wallonia')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("wallonia_expensive_MM.jpg")

plt.show()

# %%
# Filter the dataset for Wallonia
wallonia_dataset = immo_dataset[immo_dataset['region'] == 'Wallonie']

# Group by postal code and calculate the average price, median price, and price per square meter
postal_code_stats = wallonia_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)


# Get the least expensive postal codes
most_expensive_postal_codes = postal_code_stats.nlargest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = most_expensive_postal_codes['price_per_sqm']
labels = most_expensive_postal_codes.index


fig, ax = plt.subplots()
width = 0.35
ax.bar(labels, price_per_square_meter_values)
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price per Square Meter')
ax.set_title('Price per Square Meter - Most Expensive Municipalities in Wallonia')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("Wallonia_expensive_PSQM.jpg")
plt.show()

# %% [markdown]
# What are the most expensive municipalities in Flanders? (Average price, median price, price per square meter)

# %%
# Filter the dataset for Flanders
flanders_dataset = immo_dataset[immo_dataset['region'] == 'Flanders']

# Group by postal code and calculate the average price, median price
postal_code_stats = flanders_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)

# Sort the postal codes based on the average price in ascending order
most_expensive_postal_codes_average = postal_code_stats.nlargest(10, 'average_price')
most_expensive_postal_codes_median = postal_code_stats.nlargest(10, 'median_price')

labels = most_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()
width = 0.35
ax.bar(x - width/2, most_expensive_postal_codes_average['average_price'], width, label='Mean')
ax.bar(x + width/2, most_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price')
ax.set_title('Mean and Median Comparison - Most Expensive Municipalities in Flanders')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("Flanders_expensive_MM.jpg")
plt.show()

# %%
# Filter the dataset for Flanders
flanders_dataset = immo_dataset[immo_dataset['region'] == 'Flanders']

# Group by postal code and calculate the price per square meter
postal_code_stats = flanders_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)

# Get the least expensive postal codes
most_expensive_postal_codes = postal_code_stats.nlargest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = most_expensive_postal_codes['price_per_sqm']
labels = most_expensive_postal_codes.index

fig, ax = plt.subplots()
width = 0.35
ax.bar(labels, price_per_square_meter_values)
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price per Square Meter')
ax.set_title('Price per Square Meter - Most Expensive Municipalities in Flanders')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("Flanders_expensive_PSQM.jpg")
plt.show()

# %% [markdown]
# What are the less expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %%
# Calculate price per square meter
immo_dataset['price_per_sqm'] = immo_dataset['price'] / immo_dataset['habitable_surface']

# Group by region and calculate the average price, median price, and price per square meter
region_stats = immo_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median')    
)

# Sort the regions based on the index (region names) in ascending order
sorted_regions = region_stats.sort_index()

# Sort the regions based on the average price in descending order
least_expensive_regions = region_stats.sort_values(by='average_price', ascending=True).head(5)

# Print the most expensive regions and their corresponding statistics
print("Less Expensive Regions in Belgium:")
print(least_expensive_regions)
# Out:
# Less Expensive Regions in Belgium:
#              average_price  median_price
# postal_code
# 6182               59000.0       59000.0
# 6464               65000.0       65000.0
# 4830               89000.0       89000.0
# 5572               90000.0       90000.0
# 4821               92000.0       92000.0

# %%
# Calculate price per square meter
immo_dataset['price_per_sqm'] = immo_dataset['price'] / immo_dataset['habitable_surface']

# Group by postal code and calculate the average price, median price, and price per square meter
postal_code_stats = immo_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)
# Sort the postal codes based on the average price in ascending order
least_expensive_postal_codes_average = postal_code_stats.nsmallest(10, 'average_price')
least_expensive_postal_codes_median = postal_code_stats.nsmallest(10, 'median_price')

labels = least_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()

width = 0.35

ax.bar(x - width/2, least_expensive_postal_codes_average['average_price'], width, label='Mean')
ax.bar(x + width/2, least_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')

ax.set_xlabel('Municipalities')
ax.set_ylabel('Price')
ax.set_title('Mean and Median Comparison - Less Expensive Municipalities in Belgium')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("belgium_cheapest_MM.jpg")
plt.show()

# %%
# Group by postal code and calculate the average price, median price, and price per square meter
postal_code_stats = immo_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)

# Get the least expensive postal codes
least_expensive_postal_codes = postal_code_stats.nsmallest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = least_expensive_postal_codes['price_per_sqm']
labels = least_expensive_postal_codes.index

fig, ax = plt.subplots()
width = 0.35
ax.bar(labels, price_per_square_meter_values)
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price per Square Meter')
ax.set_title('Price per Square Meter - Less Expensive Municipalities in Belgium')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("belgium_cheapest_PSQM.jpg")

plt.show()

# %% [markdown]
# What are the less expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %%
# Filter the dataset for Wallonia
wallonia_dataset = immo_dataset[immo_dataset['region'] == 'Wallonie']

# Group by postal code and calculate the average price, median price
postal_code_stats = wallonia_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)

# Sort the postal codes based on the average price in ascending order
least_expensive_postal_codes_average = postal_code_stats.nsmallest(10, 'average_price')
least_expensive_postal_codes_median = postal_code_stats.nsmallest(10, 'median_price')

labels = least_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()
width = 0.35
ax.bar(x - width/2, least_expensive_postal_codes_average['average_price'], width, label='Mean',)
ax.bar(x + width/2, least_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')
#ax.bar(x + width, price_per_square_meter_values, width, label='Price per square meter', color='green')

ax.set_xlabel('Municipalities')
ax.set_ylabel('Price')
ax.set_title('Mean and Median Comparison - Less Expensive Municipalities in Wallonia')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("walloinia_cheapest_MM.jpg")

plt.show()

# %%
# Filter the dataset for Wallonia
wallonia_dataset = immo_dataset[immo_dataset['region'] == 'Wallonie']

# Group by postal code and calculate the price per square meter
postal_code_stats = wallonia_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)

# Get the least expensive postal codes
least_expensive_postal_codes = postal_code_stats.nsmallest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = least_expensive_postal_codes['price_per_sqm']
labels = least_expensive_postal_codes.index

fig, ax = plt.subplots()
width = 0.35
ax.bar(labels, price_per_square_meter_values)
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price per Square Meter')
ax.set_title('Price per Square Meter - Less Expensive Municipalities in Wallonia')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("walloinia_cheapest_PSQM.jpg")

plt.show()

# %% [markdown]
# What are the less expensive municipalities in Flanders? (Average price, median price, price per square meter)

# %%
# Filter the dataset for Flanders
flanders_dataset = immo_dataset[immo_dataset['region'] == 'Flanders']

# Group by postal code and calculate the average price, median price
postal_code_stats = flanders_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)

# Sort the postal codes based on the average price in ascending order
least_expensive_postal_codes_average = postal_code_stats.nsmallest(10, 'average_price')
least_expensive_postal_codes_median = postal_code_stats.nsmallest(10, 'median_price')

labels = least_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()
width = 0.35
ax.bar(x - width/2, least_expensive_postal_codes_average['average_price'], width, label='Mean')
ax.bar(x + width/2, least_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')

ax.set_xlabel('Municipalities')
ax.set_ylabel('Price')
ax.set_title('Mean and Median Comparison - Less Expensive Municipalities in Flanders')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("Flanders_cheapest_MM.jpg")

plt.show()

# %%
# Filter the dataset for Flanders
flanders_dataset = immo_dataset[immo_dataset['region'] == 'Flanders']

# Group by postal code and calculate the price per square meter
postal_code_stats = flanders_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)
# Get the least expensive postal codes
least_expensive_postal_codes = postal_code_stats.nsmallest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = least_expensive_postal_codes['price_per_sqm']
labels = least_expensive_postal_codes.index

fig, ax = plt.subplots()
width = 0.35
ax.bar(labels, price_per_square_meter_values)
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price per Square Meter')
ax.set_title('Price per Square Meter - Less Expensive Municipalities in Flanders')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("Flanders_cheapeat_PSQM.jpg")

plt.show()

# %%
# Filter the dataset for Flanders
brussels_dataset = immo_dataset[immo_dataset['region'] == 'Brussels']

# Group by postal code and calculate the price per square meter
postal_code_stats = brussels_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)
# Get the least expensive postal codes
least_expensive_postal_codes = postal_code_stats.nsmallest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = least_expensive_postal_codes['price_per_sqm']
labels = least_expensive_postal_codes.index

fig, ax = plt.subplots()
width = 0.35
ax.bar(labels, price_per_square_meter_values)
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price per Square Meter')
ax.set_title('Price per Square Meter - Less Expensive Municipalities in Brussels')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("brussels_cheapeat_PSQM.jpg")

plt.show()

# %%
# Filter the dataset for Flanders
brussels_dataset = immo_dataset[immo_dataset['region'] == 'Brussels']

# Group by postal code and calculate the average price, median price
postal_code_stats = brussels_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)

# Sort the postal codes based on the average price in ascending order
least_expensive_postal_codes_average = postal_code_stats.nsmallest(10, 'average_price')
least_expensive_postal_codes_median = postal_code_stats.nsmallest(10, 'median_price')

labels = least_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()
width = 0.35
ax.bar(x - width/2, least_expensive_postal_codes_average['average_price'], width, label='Mean')
ax.bar(x + width/2, least_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')

ax.set_xlabel('Municipalities')
ax.set_ylabel('Price')
ax.set_title('Mean and Median Comparison - Less Expensive Municipalities in Brussels')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("Brussels_cheapest_MM.jpg")

# %%
brussels_dataset = immo_dataset[immo_dataset['region'] == 'Brussels']

# Group by postal code and calculate the average price andmedian price
postal_code_stats = brussels_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
)

# Sort the postal codes based on the average price in ascending order
most_expensive_postal_codes_average = postal_code_stats.nlargest(10, 'average_price')
most_expensive_postal_codes_median = postal_code_stats.nlargest(10, 'median_price')

labels = most_expensive_postal_codes_average.index
x = np.arange(len(labels))

fig, ax = plt.subplots()

width = 0.35

ax.bar(x - width/2, most_expensive_postal_codes_average['average_price'], width, label='Mean')
ax.bar(x + width/2, most_expensive_postal_codes_median['median_price'], width, label='Median', color='orange')

ax.set_xlabel('Municipalities')
ax.set_ylabel('Price in euros')
ax.set_title('Mean and Median Comparison - Most Expensive Municipalities in Brussels')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.savefig("brussels_expensive_MM.jpg")

plt.show()

# %%
# Filter the dataset for Wallonia
brussels_dataset = immo_dataset[immo_dataset['region'] == 'Brussels']

# Group by postal code and calculate the average price, median price, and price per square meter
postal_code_stats = brussels_dataset.groupby('postal_code').agg(
    average_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_per_sqm=('price_per_sqm', 'mean')
)


# Get the least expensive postal codes
most_expensive_postal_codes = postal_code_stats.nlargest(10, 'price_per_sqm')

# Extract the price per square meter values and labels
price_per_square_meter_values = most_expensive_postal_codes['price_per_sqm']
labels = most_expensive_postal_codes.index


fig, ax = plt.subplots()
width = 0.35
ax.bar(labels, price_per_square_meter_values)
ax.set_xlabel('Municipalities')
ax.set_ylabel('Price per Square Meter')
ax.set_title('Price per Square Meter - Most Expensive Municipalities in Brussels')
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("brussels_expensive_PSQM.jpg")
plt.show()
