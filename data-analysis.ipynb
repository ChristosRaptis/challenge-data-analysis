# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import networkx as nx

# %%
immo_dataset = pd.read_csv('get11kdata.csv')

immo_dataset.head()
# Out:
#      locality property_type subtype_property   price      type_of_sale
# 0     Hasselt     APARTMENT        APARTMENT  390000  residential_sale  \
# 1       Liège     APARTMENT        APARTMENT  125000  residential_sale
# 2        Gent     APARTMENT        APARTMENT  375000  residential_sale
# 3    Waterloo         HOUSE            HOUSE  425000  residential_sale
# 4  Buggenhout         HOUSE            HOUSE  435000  residential_sale
#
#    number_of_rooms  living_area kitchen_fully_equiped is_furnished
# 0                2          NaN                   NaN           No  \
# 1                1          NaN                   NaN           No
# 2                3          NaN                   NaN           No
# 3                3         25.0                    No           No
# 4                6          NaN                   NaN           No
#
#   has_open_fire has_terrace  terrace_area has_garden  garden_surface
# ...

# %%
immo_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11283 entries, 0 to 11282
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   locality               11283 non-null  object
#  1   property_type          11283 non-null  object
#  2   subtype_property       11283 non-null  object
#  3   price                  11283 non-null  int64
#  4   type_of_sale           11283 non-null  object
#  5   number_of_rooms        11283 non-null  int64
#  6   living_area            3408 non-null   float64
#  7   kitchen_fully_equiped  3408 non-null   object
#  8   is_furnished           11283 non-null  object
#  9   has_open_fire          11283 non-null  object
#  10  has_terrace            11283 non-null  object
#  11  terrace_area           4658 non-null   float64
#  12  has_garden             11283 non-null  object
#  13  garden_surface         2465 non-null   float64
# ...

# %% [markdown]
# Data Cleaning
#
# Fill empty values

# %%
immo_dataset = immo_dataset.replace({'Yes': 1, 'No': 0}) 
immo_dataset.head(40)
# Out:
#               locality property_type subtype_property    price
# 0              Hasselt     APARTMENT        APARTMENT   390000  \
# 1                Liège     APARTMENT        APARTMENT   125000
# 2                 Gent     APARTMENT        APARTMENT   375000
# 3             Waterloo         HOUSE            HOUSE   425000
# 4           Buggenhout         HOUSE            HOUSE   435000
# 5             Verviers         HOUSE            HOUSE   260000
# 6                 Gent     APARTMENT        APARTMENT   174000
# 7          La Louviere     APARTMENT        APARTMENT   299999
# 8   Wenduine (De Haan)     APARTMENT        APARTMENT   129000
# 9     Vilvoorde Peutie         HOUSE            HOUSE   339000
# 10          Courcelles         HOUSE            HOUSE   399900
# 11           Grivegnée     APARTMENT        APARTMENT   150000
# 12        Boussu Hornu         HOUSE            HOUSE    95000
# 13             Berchem     APARTMENT        APARTMENT   337000
# ...

# %% [markdown]
# Data Analysis

# %%
immo_dataset.shape
# Out:
# (11283, 19)

# %%
immo_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11283 entries, 0 to 11282
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   locality               11283 non-null  object
#  1   property_type          11283 non-null  object
#  2   subtype_property       11283 non-null  object
#  3   price                  11283 non-null  int64
#  4   type_of_sale           11283 non-null  object
#  5   number_of_rooms        11283 non-null  int64
#  6   living_area            3408 non-null   float64
#  7   kitchen_fully_equiped  3408 non-null   float64
#  8   is_furnished           11283 non-null  int64
#  9   has_open_fire          11283 non-null  int64
#  10  has_terrace            11283 non-null  int64
#  11  terrace_area           4658 non-null   float64
#  12  has_garden             11283 non-null  int64
#  13  garden_surface         2465 non-null   float64
# ...

# %%
correlation_coefficient = immo_dataset['price'].corr(immo_dataset['habitable_surface'])
print(correlation_coefficient)
# Out:
# 0.5241939716564977

# %% [markdown]
# Find correlation between price and other variables

# %%
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)


def assign_region(locality):
    if locality in  ['Brussels', 'Ixelles', 'Etterbeek', 'Anderlecht', 'Schaarbeek', 'Molenbeek-Saint-Jean', 'Saint-Gilles', 'Uccle', 'Forest', 'Woluwe-Saint-Pierre', 'Woluwe-Saint-Lambert', 'Saint-Josse-ten-Noode', 'Evere', 'Ganshoren', 'Berchem-Sainte-Agathe', 'Koekelberg', 'Jette', 'Watermael-Boitsfort', 'Auderghem', 'Haren', 'Elsene']:  # List of localities in Brussels
        return 'Brussels'
    elif locality in ['Andenne', 'Ath', 'Beaumont', 'Binche', 'Bouillon', 'Charleroi', 'Chimay', 'Ciney', 'Couvin', 'Dinant', 'Doische', 'Durbuy', 'Erquelinnes', 'Fleurus', 'Florennes', 'Fontaine-l\'Evêque', 'Fosses-la-Ville', 'Gerpinnes', 'Hamois', 'Jemeppe-sur-Sambre', 'La Louvière', 'Le Roeulx', 'Lobbes', 'Mettet', 'Mons', 'Montigny-le-Tilleul', 'Mouscron', 'Namur', 'Nivelles', 'Peruwelz', 'Philippeville', 'Seneffe', 'Sivry-Rance', 'Soignies', 'Thuin', 'Tournai', 'Viroinval', 'Walcourt', 'Yvoir']:  # List of localities in Wallonia
        return 'Wallonia'
    else:  
        return 'Flanders'

immo_dataset['region'] = immo_dataset['locality'].apply(assign_region)

numeric_variable = immo_dataset.select_dtypes(include=['int', 'float'])
non_numeric_variable = immo_dataset.select_dtypes(include=['object'])
non_numeric_variable=non_numeric_variable.drop('locality',axis=1)
dummy_variables = pd.get_dummies(non_numeric_variable)
combined_data = pd.concat([numeric_variable, dummy_variables], axis=1)
correlation_matrix = combined_data.corr()['price'].drop('price')



print(correlation_matrix)
# Out:
# number_of_rooms                                  0.344995
# living_area                                      0.121042
# kitchen_fully_equiped                            0.296847
# is_furnished                                     0.014979
# has_open_fire                                   -0.035291
# has_terrace                                      0.095502
# terrace_area                                     0.292424
# has_garden                                       0.052015
# garden_surface                                   0.071479
# habitable_surface                                0.524194
# plot_land_surface                                0.273120
# number_of_facades                                0.145207
# has_swimming_pool                                0.227565
# property_type_APARTMENT                         -0.037392
# property_type_HOUSE                              0.037392
# subtype_property_APARTMENT                      -0.037392
# ...

# %% [markdown]
# How are variables correlated to each other?

# %% [markdown]
# Which variables have the greatest influence on the price?

# %% [markdown]
# Which variables have the least influence on the price?

# %% [markdown]
# How many qualitative and quantitative variables are there? How would you transform these values into numerical values?

# %% [markdown]
# Percentage of missing values per column?
#
# https://campus.datacamp.com/courses/data-manipulation-with-pandas/creating-and-visualizing-dataframes?ex=6
#
# https://campus.datacamp.com/courses/dealing-with-missing-data-in-python/the-problem-with-missing-data?ex=5

# %%
missing_percentage = immo_dataset.isna().mean() * 100
print(missing_percentage)
# Out:
# locality                  0.000000
# property_type             0.000000
# subtype_property          0.000000
# price                     0.000000
# type_of_sale              0.000000
# number_of_rooms           0.000000
# living_area              69.795267
# kitchen_fully_equiped    69.795267
# is_furnished              0.000000
# has_open_fire             0.000000
# has_terrace               0.000000
# terrace_area             58.716653
# has_garden                0.000000
# garden_surface           78.152973
# habitable_surface         5.432952
# plot_land_surface        75.990428
# number_of_facades        74.324205
# has_swimming_pool         0.000000
# building_state           73.367012
# region                    0.000000
# dtype: float64

# %% [markdown]
# Step 3 : Data Interpretation

# %% [markdown]
# Plot the outliers.

# %% [markdown]
# Which variables would you delete and why ?

# %% [markdown]
# Represent the number of properties according to their surface using a histogram.

# %% [markdown]
# In your opinion, which 5 variables are the most important and why?

# %% [markdown]
# What are the most expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %% [markdown]
# What are the most expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %% [markdown]
# What are the most expensive municipalities in Flanders? (Average price, median price, price per square meter)

# %% [markdown]
# What are the less expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %% [markdown]
# What are the less expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %% [markdown]
# What are the less expensive municipalities in Flanders? (Average price, median price, price per square meter)
